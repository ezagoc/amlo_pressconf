# %%
import pandas as pd
import numpy as np

fol = '../../../data/06-outcomes/youtube/big_channels/'

df = pd.read_parquet(f'{fol}aztecanoticias.parquet')
df
# Out:
#           videoId                                              title  \
# 0     WGyct4sUEwg  Campañeando: en Nuevo León ya comenzaron los z...
# 1     6-rSgcg2H6M  Combatientes trabajan por tierra y aire para a...
# 2     7sTjT1VAyes  Crónica: Así se vivió el incendio forestal en ...
# 3     2hk8usMxdQE  Evacúan a vecinos de colonia Lomas de Padierna...
# 4     -icbwfJcAEQ  Sin llamas por incendio forestal al sur de la ...
# ...           ...                                                ...
# 2319  o0E-8MAPRcY              "John" se aproxima a Colima | ver ➕👆🏼
# 2320  LPiThM8X0fI  #ProhibidoProhibir | La iniciativa a Ley de Ar...
# 2321  ykXUmKov5b4  EU empieza a limpiar los destrozos que dejó el...
# 2322  kwSjRQVvA7s  En Acapulco, Guerrero, las casas quedaron bajo...
# 2323  nTKeM3YN0KM  EN RUINAS | Tras el paso del huracán "John", v...
#
#                                             description           publishedAt  \
# ...
